# %%
from files.scene import *
from files.multiscene import *
from files.IN import *

# %% [markdown]
# # Data Creation
#
# ## Scene creation

# %%
#No interaction scene
escena_no_interaction = Scene(n_body=3, R_init=polygon_init, V_init=polygon_init, r=0.1, v=0.01, dt=1)
escena_no_interaction.simulate(interaction=zero_interaction, t_steps=100)

#Central force scene
escena_central_force = Scene(n_body=3, R_init=random_init, V_init=random_init, r=0.1, v=8e-3, dt=1)
escena_central_force.simulate(interaction=central_force, t_steps=100, alpha=1e-4, beta=0)

#Vicsek model scene
escena_vicsek = Scene(n_body=6,  R_init=random_init, V_init=random_init, r=0.6, v=1e-1, dt=1)
escena_vicsek.simulate(interaction=vicsek, t_steps=100, radius=0.4, angle_vision=np.pi)

# %%
fig, ax = plt.subplots(1,3,figsize=(15,5))

for axi, scene, title in zip(ax,[escena_no_interaction, escena_central_force, escena_vicsek], ['no interaction', 'central force', 'Vicsek model']):
    axi.set_xlim(-1,1)
    axi.set_ylim(-1,1)
    axi.set_title(title)
    axi.tick_params(labelbottom=False, labelleft=False, right=False, top=False, bottom=False, left=False)
    scene.plot_trajectory(who='truth', ax=axi)
    axi.legend()
plt.show()

# %% [markdown]
# ## Multiscene creation

# %%
n_scenes = 3
t_steps = 100
ms = MultiScene()
ms.add_bunch(n_scenes=n_scenes, n_body=5, t_steps=100, R_init=random_init, V_init=random_init, dt=1, r=2e-1, v=5e-2, interaction=zero_interaction)
ms.add_bunch(n_scenes=n_scenes, n_body=5, t_steps=t_steps, R_init=random_init, V_init=random_init, dt=1, r=7.5e-1, v=8e-3, interaction=central_force, alpha=1e-4, beta=0)
ms.add_bunch(n_scenes=n_scenes, n_body=5, t_steps=t_steps, R_init=random_init, V_init=polygon_init, r=6e-1, v=1e-2, interaction=vicsek, radius=2.5e-1)
ms.save('data/demo_multiscene')

ms = MultiScene(load='data/demo_multiscene')

# %%
fig, ax = plt.subplots(3,3,figsize=(15,15))
scene_i = 0
for axi,title in zip(ax, ['no interaction', 'central force', 'Vicsek model']):
    for axij in axi:
        axij.set_xlim(-1,1)
        axij.set_ylim(-1,1)
        axij.set_title(title+ f' scene:{scene_i}')
        axij.tick_params(labelbottom=False, labelleft=False, right=False, top=False, bottom=False, left=False)
        ms(scene_i).plot_trajectory(who='truth', ax=axij)
        axij.legend()
        scene_i +=1
plt.show()

# %% [markdown]
# ## Creating Training and Validation Datasets

# %%
n_scenes = 100
t_steps = 100
ms = MultiScene()
ms.add_bunch(n_scenes=n_scenes, n_body=5, t_steps=100, R_init=random_init, V_init=random_init, dt=1, r=4e-1, v=5e-2, interaction=zero_interaction)
ms.save('data/demo_train')

ms = MultiScene()
ms.add_bunch(n_scenes=n_scenes, n_body=5, t_steps=100, R_init=random_init, V_init=random_init, dt=1, r=2e-1, v=5e-2, interaction=zero_interaction)
ms.save('data/demo_val')

# %% [markdown]
# ### Extracting the features and targets

# %%
ms_train = MultiScene(load='data/demo_train')
X_train = ms_train.get_features(joint=True) #features
V_train = ms_train.get_target(var='V', joint=True) #target velocities
A_train = ms_train.get_target(var='A', joint=True) #target accelerations

ms_val = MultiScene(load='data/demo_val')
X_val = ms_val.get_features(joint=True) #features
V_val = ms_val.get_target(var='V', joint=True) #target velocities
A_val = ms_val.get_target(var='A', joint=True) #target accelerations

# %% [markdown]
# # CREATING A MODEL
#
# ## Training

# %%
IN = InteractionNetwork(D_E=2, R_hidden_layers=[], O_hidden_layers=[], output_var='A', self_edges=False,  aggregator='sum', include_v=False, name='demo_model')
IN.fit(X_train, A_train, validation=(X_val, A_val), learning_rate=1e-1, epochs=10000, print_every=100)
IN.save('saved_models/'+IN._name)
# Out:
# Epoch( 100/ 10000) Loss:9.1000e-06 Validation Loss:8.5694e-06
# Epoch( 200/ 10000) Loss:6.1405e-07 Validation Loss:5.9817e-07
# Epoch( 300/ 10000) Loss:3.7159e-07 Validation Loss:3.8510e-07
# Epoch( 400/ 10000) Loss:3.6341e-07 Validation Loss:3.8029e-07
# Epoch( 500/ 10000) Loss:3.6219e-07 Validation Loss:3.7956e-07
# Epoch( 600/ 10000) Loss:3.6118e-07 Validation Loss:3.7859e-07
# Epoch( 700/ 10000) Loss:3.6017e-07 Validation Loss:3.7756e-07
# Epoch( 800/ 10000) Loss:3.5917e-07 Validation Loss:3.7651e-07
# Epoch( 900/ 10000) Loss:3.5818e-07 Validation Loss:3.7547e-07
# Epoch( 1000/ 10000) Loss:3.5718e-07 Validation Loss:3.7442e-07
# Epoch( 1100/ 10000) Loss:3.5619e-07 Validation Loss:3.7339e-07
# Epoch( 1200/ 10000) Loss:3.5521e-07 Validation Loss:3.7235e-07
# Epoch( 1300/ 10000) Loss:3.5422e-07 Validation Loss:3.7132e-07
# Epoch( 1400/ 10000) Loss:3.5324e-07 Validation Loss:3.7029e-07
# Epoch( 1500/ 10000) Loss:3.5227e-07 Validation Loss:3.6927e-07
# Epoch( 1600/ 10000) Loss:3.5129e-07 Validation Loss:3.6825e-07
# Epoch( 1700/ 10000) Loss:3.5032e-07 Validation Loss:3.6723e-07
# Epoch( 1800/ 10000) Loss:3.4936e-07 Validation Loss:3.6622e-07
# Epoch( 1900/ 10000) Loss:3.4839e-07 Validation Loss:3.6521e-07
# Epoch( 2000/ 10000) Loss:3.4743e-07 Validation Loss:3.6420e-07
# Epoch( 2100/ 10000) Loss:3.4647e-07 Validation Loss:3.6320e-07
# Epoch( 2200/ 10000) Loss:3.4552e-07 Validation Loss:3.6220e-07
# Epoch( 2300/ 10000) Loss:3.4457e-07 Validation Loss:3.6120e-07
# Epoch( 2400/ 10000) Loss:3.4362e-07 Validation Loss:3.6021e-07
# Epoch( 2500/ 10000) Loss:3.4268e-07 Validation Loss:3.5922e-07
# Epoch( 2600/ 10000) Loss:3.4174e-07 Validation Loss:3.5823e-07
# Epoch( 2700/ 10000) Loss:3.4080e-07 Validation Loss:3.5725e-07
# Epoch( 2800/ 10000) Loss:3.3986e-07 Validation Loss:3.5627e-07
# Epoch( 2900/ 10000) Loss:3.3893e-07 Validation Loss:3.5529e-07
# Epoch( 3000/ 10000) Loss:3.3800e-07 Validation Loss:3.5431e-07
# Epoch( 3100/ 10000) Loss:3.3707e-07 Validation Loss:3.5334e-07
# Epoch( 3200/ 10000) Loss:3.3615e-07 Validation Loss:3.5237e-07
# Epoch( 3300/ 10000) Loss:3.3523e-07 Validation Loss:3.5141e-07
# Epoch( 3400/ 10000) Loss:3.3431e-07 Validation Loss:3.5044e-07
# Epoch( 3500/ 10000) Loss:3.3339e-07 Validation Loss:3.4948e-07
# Epoch( 3600/ 10000) Loss:3.3248e-07 Validation Loss:3.4853e-07
# Epoch( 3700/ 10000) Loss:3.3157e-07 Validation Loss:3.4758e-07
# Epoch( 3800/ 10000) Loss:3.3066e-07 Validation Loss:3.4662e-07
# Epoch( 3900/ 10000) Loss:3.2976e-07 Validation Loss:3.4568e-07
# Epoch( 4000/ 10000) Loss:3.2886e-07 Validation Loss:3.4473e-07
# Epoch( 4100/ 10000) Loss:3.2796e-07 Validation Loss:3.4379e-07
# Epoch( 4200/ 10000) Loss:3.2706e-07 Validation Loss:3.4285e-07
# Epoch( 4300/ 10000) Loss:3.2617e-07 Validation Loss:3.4191e-07
# Epoch( 4400/ 10000) Loss:3.2528e-07 Validation Loss:3.4098e-07
# Epoch( 4500/ 10000) Loss:3.2439e-07 Validation Loss:3.4005e-07
# Epoch( 4600/ 10000) Loss:3.2351e-07 Validation Loss:3.3913e-07
# Epoch( 4700/ 10000) Loss:3.2263e-07 Validation Loss:3.3820e-07
# Epoch( 4800/ 10000) Loss:3.2175e-07 Validation Loss:3.3728e-07
# Epoch( 4900/ 10000) Loss:3.2088e-07 Validation Loss:3.3637e-07
# Epoch( 5000/ 10000) Loss:3.2001e-07 Validation Loss:3.3545e-07
# Epoch( 5100/ 10000) Loss:3.1914e-07 Validation Loss:3.3454e-07
# Epoch( 5200/ 10000) Loss:3.1827e-07 Validation Loss:3.3364e-07
# Epoch( 5300/ 10000) Loss:3.1741e-07 Validation Loss:3.3273e-07
# Epoch( 5400/ 10000) Loss:3.1655e-07 Validation Loss:3.3183e-07
# Epoch( 5500/ 10000) Loss:3.1569e-07 Validation Loss:3.3093e-07
# Epoch( 5600/ 10000) Loss:3.1483e-07 Validation Loss:3.3003e-07
# Epoch( 5700/ 10000) Loss:3.1398e-07 Validation Loss:3.2914e-07
# Epoch( 5800/ 10000) Loss:3.1313e-07 Validation Loss:3.2825e-07
# Epoch( 5900/ 10000) Loss:3.1228e-07 Validation Loss:3.2736e-07
# Epoch( 6000/ 10000) Loss:3.1144e-07 Validation Loss:3.2647e-07
# Epoch( 6100/ 10000) Loss:3.1060e-07 Validation Loss:3.2559e-07
# Epoch( 6200/ 10000) Loss:3.0976e-07 Validation Loss:3.2471e-07
# Epoch( 6300/ 10000) Loss:3.0892e-07 Validation Loss:3.2383e-07
# Epoch( 6400/ 10000) Loss:3.0808e-07 Validation Loss:3.2296e-07
# Epoch( 6500/ 10000) Loss:3.0725e-07 Validation Loss:3.2208e-07
# Epoch( 6600/ 10000) Loss:3.0642e-07 Validation Loss:3.2121e-07
# Epoch( 6700/ 10000) Loss:3.0560e-07 Validation Loss:3.2035e-07
# Epoch( 6800/ 10000) Loss:3.0477e-07 Validation Loss:3.1948e-07
# Epoch( 6900/ 10000) Loss:3.0395e-07 Validation Loss:3.1862e-07
# Epoch( 7000/ 10000) Loss:3.0313e-07 Validation Loss:3.1776e-07
# Epoch( 7100/ 10000) Loss:3.0232e-07 Validation Loss:3.1691e-07
# Epoch( 7200/ 10000) Loss:3.0150e-07 Validation Loss:3.1605e-07
# Epoch( 7300/ 10000) Loss:3.0069e-07 Validation Loss:3.1520e-07
# Epoch( 7400/ 10000) Loss:2.9988e-07 Validation Loss:3.1435e-07
# Epoch( 7500/ 10000) Loss:2.9907e-07 Validation Loss:3.1351e-07
# Epoch( 7600/ 10000) Loss:2.9827e-07 Validation Loss:3.1266e-07
# Epoch( 7700/ 10000) Loss:2.9746e-07 Validation Loss:3.1182e-07
# Epoch( 7800/ 10000) Loss:2.9666e-07 Validation Loss:3.1098e-07
# Epoch( 7900/ 10000) Loss:2.9587e-07 Validation Loss:3.1014e-07
# Epoch( 8000/ 10000) Loss:2.9507e-07 Validation Loss:3.0931e-07
# Epoch( 8100/ 10000) Loss:2.9428e-07 Validation Loss:3.0848e-07
# Epoch( 8200/ 10000) Loss:2.9349e-07 Validation Loss:3.0766e-07
# Epoch( 8300/ 10000) Loss:2.9271e-07 Validation Loss:3.0683e-07
# Epoch( 8400/ 10000) Loss:2.9193e-07 Validation Loss:3.0601e-07
# Epoch( 8500/ 10000) Loss:2.9115e-07 Validation Loss:3.0519e-07
# Epoch( 8600/ 10000) Loss:2.9037e-07 Validation Loss:3.0438e-07
# Epoch( 8700/ 10000) Loss:2.8959e-07 Validation Loss:3.0356e-07
# Epoch( 8800/ 10000) Loss:2.8882e-07 Validation Loss:3.0275e-07
# Epoch( 8900/ 10000) Loss:2.8804e-07 Validation Loss:3.0194e-07
# Epoch( 9000/ 10000) Loss:2.8728e-07 Validation Loss:3.0114e-07
# Epoch( 9100/ 10000) Loss:2.8651e-07 Validation Loss:3.0033e-07
# Epoch( 9200/ 10000) Loss:2.8574e-07 Validation Loss:2.9953e-07
# Epoch( 9300/ 10000) Loss:2.8498e-07 Validation Loss:2.9873e-07
# Epoch( 9400/ 10000) Loss:2.8422e-07 Validation Loss:2.9793e-07
# Epoch( 9500/ 10000) Loss:2.8346e-07 Validation Loss:2.9714e-07
# Epoch( 9600/ 10000) Loss:2.8271e-07 Validation Loss:2.9635e-07
# Epoch( 9700/ 10000) Loss:2.8195e-07 Validation Loss:2.9556e-07
# Epoch( 9800/ 10000) Loss:2.8120e-07 Validation Loss:2.9477e-07
# Epoch( 9900/ 10000) Loss:2.8045e-07 Validation Loss:2.9398e-07
# Epoch( 10000/ 10000) Loss:2.7971e-07 Validation Loss:2.9320e-07

# %% [markdown]
# ### Visualizing the loss evolution for training and validation

# %%
plt.plot([np.log10(x) for x in IN.history['loss']], label='training loss')
plt.plot([np.log10(x) for x in IN.history['validation']], label='validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Computing position MSE for different length mulstistep rollout predictions

# %%
ms_val.predict_trajectory(IN)
ms_val.compute_mse()
ms_val.save('data/demo_val')

# %%
fig, ax = plt.subplots( figsize=(12,6.))
ms_val.plot_mse(ax=ax)
ax.legend(loc="lower center", bbox_to_anchor=(0.6, 0.1), ncol=2)
ax.set_ylim(top=-0, bottom=-9)
ax.set_xlim(right=20, left=0)
plt.show()

# %% [markdown]
# ### Visualizing multistep rollout predictions

# %%
n_scenes = 3
hspace = 0.0
wspace = 0.0

fig, ax = plt.subplots(n_scenes,2, figsize=(10,15))
for i, axi in enumerate(ax):
  # ms_val(i).plot_trajectory_comparison(model=nv2, ax=axi)
  for axii,model in zip(axi,['truth', 'demo_model']):
    ms_val(i+10).plot_trajectory_tex(who=model, ax=axii)
    if i==0: axii.set_title(f'{model}')
    if model=='truth': axii.set_ylabel(f'Scene {i+1}')
    axii.set_xlim(-1,1)
    axii.set_ylim(-1,1)
    # axii.tick_params(direction='in')
    axii.tick_params(labelbottom=False, labelleft=False, right=False, top=False, bottom=False, left=False)
    # if i==0:axii.legend()
  plt.subplots_adjust(wspace=wspace, hspace=hspace)
plt.show()
