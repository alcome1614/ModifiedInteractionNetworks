# %%
from multiscene import *
from IN import *
from naive import *

# %% [markdown]
# # SIMULATION OF PHYSICAL SYSTEMS WITH INTERACTION NETWORKS VARIANTS
#
# ## Presentation of Results
#
# ### No Interaction

# %%
ms_val = MultiScene(load='no_interaction_val')
X_val = ms_val.get_features(joint=True) #features
V_val = ms_val.get_target(var='V', joint=True) #target velocities
A_val = ms_val.get_target(var='A', joint=True) #target accelerations

# %%
fig, ax = plt.subplots( figsize=(12,6.))
ms_val.plot_mse(ax=ax)
ax.legend(loc="lower center", bbox_to_anchor=(0.6, 0.1), ncol=2)
ax.set_xlim(right=20, left=0)
plt.show()

# %%
n_scenes = 3
hspace = 0.0
wspace = 0.0
fig, ax = plt.subplots(n_scenes,3, figsize=(15,15))
for i, axi in enumerate(ax):
  for axii,model in zip(axi,['truth', 'IN_1', 'IN_2']):
    ms_val(i+10).plot_trajectory_tex(who=model, ax=axii)
    if i==0: axii.set_title(f'{model}')
    if model=='truth': axii.set_ylabel(f'Scene {i+1}')
    axii.set_xlim(-1,1)
    axii.set_ylim(-1,1)
    axii.tick_params(labelbottom=False, labelleft=False, right=False, top=False, bottom=False, left=False)
    axii.legend()
  plt.subplots_adjust(wspace=wspace, hspace=hspace)
plt.show()

# %% [markdown]
#    ### Central Force

# %%
ms_val = MultiScene(load='central_force_0_val')
X_val = ms_val.get_features(joint=True) #features
V_val = ms_val.get_target(var='V', joint=True) #target velocities
A_val = ms_val.get_target(var='A', joint=True) #target accelerations

# %%
fig, ax = plt.subplots( figsize=(12,6.))
ms_val.plot_mse(ax=ax)
ax.legend(loc="lower center", bbox_to_anchor=(0.6, 0.1), ncol=2)
ax.set_ylim(top=0, bottom=-8)
ax.set_xlim(right=20, left=0)
plt.show()

# %%
n_scenes = 3
hspace = 0.0
wspace = 0.0
fig, ax = plt.subplots(n_scenes,3, figsize=(15,15))
for i, axi in enumerate(ax):
  for axii,model in zip(axi,['truth', 'IN_4', 'IN_5']):
    ms_val(i+10).plot_trajectory_tex(who=model, ax=axii)
    if i==0: axii.set_title(f'{model}')
    if model=='truth': axii.set_ylabel(f'Scene {i+1}')
    axii.set_xlim(-1,1)
    axii.set_ylim(-1,1)
    axii.tick_params(labelbottom=False, labelleft=False, right=False, top=False, bottom=False, left=False)
    axii.legend()
  plt.subplots_adjust(wspace=wspace, hspace=hspace)
plt.show()

# %% [markdown]
# ### Vicsek model
# #### Experiment 1

# %%
ms_val = MultiScene(load='vicsek_1_val')
X_val = ms_val.get_features(joint=True) #features
V_val = ms_val.get_target(var='V', joint=True) #target velocities
A_val = ms_val.get_target(var='A', joint=True) #target accelerations

# %%
fig, ax = plt.subplots( figsize=(12,6.))
ms_val.plot_mse(ax=ax)
ax.legend(loc="lower center", bbox_to_anchor=(0.6, 0.1), ncol=2)
# ax.set_ylim(top=0, bottom=-6)
ax.set_xlim(right=20, left=0)
plt.show()

# %%
n_scenes = 3
hspace = 0.0
wspace = 0.0
fig, ax = plt.subplots(n_scenes,2, figsize=(15,15))
for i, axi in enumerate(ax):
  for axii,model in zip(axi,['truth', 'IN_14']):
    ms_val(i+10).plot_trajectory_tex(who=model, ax=axii)
    if i==0: axii.set_title(f'{model}')
    if model=='truth': axii.set_ylabel(f'Scene {i+1}')
    axii.set_xlim(-1,1)
    axii.set_ylim(-1,1)
    axii.tick_params(labelbottom=False, labelleft=False, right=False, top=False, bottom=False, left=False)
    axii.legend()
  plt.subplots_adjust(wspace=wspace, hspace=hspace)
plt.show()

# %% [markdown]
# #### Experiment 2

# %%
ms_val = MultiScene(load='vicsek_0_train')
X_val = ms_val.get_features(joint=True) #features
V_val = ms_val.get_target(var='V', joint=True) #target velocities
A_val = ms_val.get_target(var='A', joint=True) #target accelerations

# %%
fig, ax = plt.subplots( figsize=(12,6.))
ms_val.plot_mse(ax=ax)
ax.legend(loc="lower center", bbox_to_anchor=(0.6, 0.1), ncol=2)
ax.set_ylim(top=0, bottom=-6)
ax.set_xlim(right=20, left=0)
plt.show()

# %%
n_scenes = 3
hspace = 0.0
wspace = 0.0
fig, ax = plt.subplots(n_scenes,3, figsize=(15,15))
for i, axi in enumerate(ax):
  for axii,model in zip(axi,['truth', 'IN_11', 'IN_12']):
    ms_val(i+10).plot_trajectory_tex(who=model, ax=axii)
    if i==0: axii.set_title(f'{model}')
    if model=='truth': axii.set_ylabel(f'Scene {i+1}')
    axii.set_xlim(-1,1)
    axii.set_ylim(-1,1)
    axii.tick_params(labelbottom=False, labelleft=False, right=False, top=False, bottom=False, left=False)
    axii.legend()
  plt.subplots_adjust(wspace=wspace, hspace=hspace)
plt.show()
